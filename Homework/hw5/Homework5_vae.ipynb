# %%
# !if [ -d dul_2021 ]; then rm -Rf dul_2021; fi
# !git clone https://github.com/GrigoryBartosh/dul_2021
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF" -O hw3_data.zip && rm -rf /tmp/cookies.txt
# !unzip -qq hw3_data.zip -d dul_2021/Homework/hw5/data
# !rm hw3_data.zip
# !pip install ./dul_2021
# Out:
# Cloning into 'dul_2021'...
# remote: Enumerating objects: 235, done.
# remote: Counting objects: 100% (235/235), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 235 (delta 107), reused 157 (delta 52), pack-reused 0
# Receiving objects: 100% (235/235), 30.60 MiB | 23.82 MiB/s, done.
# Resolving deltas: 100% (107/107), done.
# --2021-12-01 14:48:32--  https://docs.google.com/uc?export=download&confirm=y9fZ&id=1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF
# Resolving docs.google.com (docs.google.com)... 142.250.217.142, 2607:f8b0:4007:818::200e
# Connecting to docs.google.com (docs.google.com)|142.250.217.142|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-50-docs.googleusercontent.com/docs/securesc/8vajvdfdufgnifnsi2jnt4q7gkfeiu4i/lac8cao60mbaei0fki4ko5tb3p75cgvn/1638370050000/06419056966375271799/06525267238800620756Z/1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF?e=download [following]
# --2021-12-01 14:48:33--  https://doc-14-50-docs.googleusercontent.com/docs/securesc/8vajvdfdufgnifnsi2jnt4q7gkfeiu4i/lac8cao60mbaei0fki4ko5tb3p75cgvn/1638370050000/06419056966375271799/06525267238800620756Z/1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF?e=download
# Resolving doc-14-50-docs.googleusercontent.com (doc-14-50-docs.googleusercontent.com)... 142.250.189.1, 2607:f8b0:4007:817::2001
# Connecting to doc-14-50-docs.googleusercontent.com (doc-14-50-docs.googleusercontent.com)|142.250.189.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=e9of3e33slaks&continue=https://doc-14-50-docs.googleusercontent.com/docs/securesc/8vajvdfdufgnifnsi2jnt4q7gkfeiu4i/lac8cao60mbaei0fki4ko5tb3p75cgvn/1638370050000/06419056966375271799/06525267238800620756Z/1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF?e%3Ddownload&hash=adojfepj5241ibdd6r3359ko9hbesof5 [following]
# --2021-12-01 14:48:33--  https://docs.google.com/nonceSigner?nonce=e9of3e33slaks&continue=https://doc-14-50-docs.googleusercontent.com/docs/securesc/8vajvdfdufgnifnsi2jnt4q7gkfeiu4i/lac8cao60mbaei0fki4ko5tb3p75cgvn/1638370050000/06419056966375271799/06525267238800620756Z/1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF?e%3Ddownload&hash=adojfepj5241ibdd6r3359ko9hbesof5
# Connecting to docs.google.com (docs.google.com)|142.250.217.142|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-14-50-docs.googleusercontent.com/docs/securesc/8vajvdfdufgnifnsi2jnt4q7gkfeiu4i/lac8cao60mbaei0fki4ko5tb3p75cgvn/1638370050000/06419056966375271799/06525267238800620756Z/1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF?e=download&nonce=e9of3e33slaks&user=06525267238800620756Z&hash=2if0c4b6qj6hltslliv005o08l67j0ql [following]
# --2021-12-01 14:48:33--  https://doc-14-50-docs.googleusercontent.com/docs/securesc/8vajvdfdufgnifnsi2jnt4q7gkfeiu4i/lac8cao60mbaei0fki4ko5tb3p75cgvn/1638370050000/06419056966375271799/06525267238800620756Z/1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF?e=download&nonce=e9of3e33slaks&user=06525267238800620756Z&hash=2if0c4b6qj6hltslliv005o08l67j0ql
# Connecting to doc-14-50-docs.googleusercontent.com (doc-14-50-docs.googleusercontent.com)|142.250.189.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 242222000 (231M) [application/zip]
# Saving to: ‘hw3_data.zip’
#
# hw3_data.zip        100%[===================>] 231.00M  41.5MB/s    in 5.9s
#
# 2021-12-01 14:48:39 (39.0 MB/s) - ‘hw3_data.zip’ saved [242222000/242222000]
#
# Processing ./dul_2021
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Building wheels for collected packages: dul-2021
#   Building wheel for dul-2021 (setup.py) ... done
#   Created wheel for dul-2021: filename=dul_2021-0.1.0-py3-none-any.whl size=19088 sha256=c219c92e7b17c7ccff9eab700d501a832811f488e0d04f6f93e031066531bae8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8c7q8w1e/wheels/55/59/29/0fb1c635652157734f4d741f32fc11979149684e83e919de06
# Successfully built dul-2021
# Installing collected packages: dul-2021
# Successfully installed dul-2021-0.1.0

# %%
from dul_2021.utils.hw5_utils import *

# %%
from typing import Tuple, List, Union

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam

# %% [markdown]
# # Question 1: VAEs on Images
# In this question, you will train VAE models on image datasets. Execute the cell below to visualize the two datasets (colored shapes, and [SVHN](http://ufldl.stanford.edu/housenumbers/)).

# %%
visualize_svhn()
visualize_cifar10()

# %% [markdown]
# ## Part (a) VAE
# In this part, implement a standard VAE with the following characteristics:
#
# *   16-dim latent variables $z$ with standard normal prior $p(z) = N(0,I)$
# *   An approximate posterior $q_\theta(z|x) = N(z; \mu_\theta(x), \Sigma_\theta(x))$, where $\mu_\theta(x)$ is the mean vector, and $\Sigma_\theta(x)$ is a diagonal covariance matrix
# *   A decoder $p(x|z) = N(x; \mu_\phi(z), I)$, where $\mu_\phi(z)$ is the mean vector. (We are not learning the covariance of the decoder)
#
# You can play around with different architectures and try for better results, but the following encoder / decoder architecture below suffices (Note that image input is always $32\times 32$.
# ```
# conv2d(in_channels, out_channels, kernel_size, stride, padding)
# transpose_conv2d(in_channels, out_channels, kernel_size, stride, padding)
# linear(in_dim, out_dim)
#
# Encoder
#     conv2d(3, 32, 3, 1, 1)
#     relu()
#     conv2d(32, 64, 3, 2, 1) # 16 x 16
#     relu()
#     conv2d(64, 128, 3, 2, 1) # 8 x 8
#     relu()
#     conv2d(128, 256, 3, 2, 1) # 4 x 4
#     relu()
#     flatten()
#     linear(4 * 4 * 256, 2 * latent_dim)
#
# Decoder
#     linear(latent_dim, 4 * 4 * 128)
#     relu()
#     reshape(4, 4, 128)
#     transpose_conv2d(128, 128, 4, 2, 1) # 8 x 8
#     relu()
#     transpose_conv2d(128, 64, 4, 2, 1) # 16 x 16
#     relu()
#     transpose_conv2d(64, 32, 4, 2, 1) # 32 x 32
#     relu()
#     conv2d(32, 3, 3, 1, 1)
# ```
#
# You may find the following training tips helpful
# *   When computing reconstruction loss and KL loss, average over the batch dimension and **sum** over the feature dimension
# *   When computing reconstruction loss, it suffices to just compute MSE between the reconstructed $x$ and true $x$ (you can compute the extra constants if you want)
# *   Use batch size 128, learning rate $10^{-3}$, and an Adam optimizer
#
#
#
#
# **You will provide the following deliverables**
#
#
# 1.   Over the course of training, record the average full negative ELBO, reconstruction loss, and KL term of the training data (per minibatch) and test data (for your entire test set). Code is provided that automatically plots the training curves.
# 2.   Report the final test set performance of your final model
# 3. 100 samples from your trained VAE
# 4. 50 real-image / reconstruction pairs (for some $x$, encode and then decode)
# 5. Interpolations of length 10 between 10 pairs of test images from your VAE (100 images total)

# %%
class UpSampleBlock(nn.Module):
    def __init__(self, dim: int) -> None:
        super().__init__()
        
        self.block = nn.Sequential(
            nn.Conv2d(dim, 2 * dim, 3, 2, 1),
            nn.ReLU()
        )
    
    def forward(x):
        return self.block(x)

class DownSampleBlock(nn.Module):
    def __init__(self, dim: int) -> None:
        super().__init__()
        

        self.block = nn.Sequential(
            nn.ConvTranspose2d(dim, dim // 2, 4, 2, 1),
            nn.ReLU()
        )
    
    def forward(x):
        return self.block(x)

# %%
class Encoder(nn.Module):
    def __init__(self,
                 start_channels: int,
                 num_hidden_layes: int = 5,
                 latent_dim: int = 16,
                 ) -> None:

        super().__init__()

        end_channels = start_channels * (1 << num_hidden_layes)

        start_layer = [
            nn.Conv2d(3, start_channels, 3, 1, 1),
            nn.ReLU()
        ]
        hidden_layers = self.get_hidden_layers(start_channels, num_hidden_layes)
        end_layer = [
            nn.Conv2d(end_channels, 2 * latent_dim, 1)
        ]

        self.model = nn.Sequential(
            *start_layer,
            *hidden_layers,
            *end_layer
        )
    
    def get_hidden_layers(self,
                          dim: int,
                          num_hidden_layes: int,
                          ) -> List[UpSampleBlock]:
        
        hidden_layers = []
        for i in range(num_hidden_layes):
            hidden_layers.append(UpSampleBlock(dim))
            dim <<= 1
        
        return hidden_layers
    
    def forward(self,
                x: torch.tensor,
                ) -> Tuple[torch.tensor, torch.tensor, torch.tensor]:

        out = self.model(x)
        mu, log_sigma = torch.chunk(out, 2, dim=1)
        return mu + torch.randn_like(mu) * log_sigma.exp(), mu, log_sigma

# %%
class Decoder(nn.Module):
    def __init__(self,
                 end_channels: int,
                 num_hidden_layes: int = 5,
                 latent_dim: int = 16,
                 ) -> None:

        super().__init__()

        start_channels = end_channels * (1 << num_hidden_layes)

        start_layer = [
            nn.Conv2d(latent_dim, start_channels, 1),
            nn.ReLU()
        ]
        hidden_layers = self.get_hidden_layers(start_channels, num_hidden_layes)
        end_layer = [
            nn.Conv2d(end_channels, 3, 1),

        ]

        self.model = nn.Sequential(
            *start_layer,
            *hidden_layers,
            *end_layer
        )
    
    def get_hidden_layers(self,
                          dim: int,
                          num_hidden_layes: int,
                          ) -> List[DownSampleBlock]:
        
        hidden_layers = []
        for i in range(num_hidden_layes):
            hidden_layers.append(DownSampleBlock(dim))
            dim >>= 1
        
        return hidden_layers
    
    def forward(self, x: torch.tensor):
        return self.model(x)

# %%
class VAE(nn.Module):
    def __init__(self,
                 img_size: int = 32,
                 start_channels:int = 32,
                 latent_dim: int = 16,
                 ) -> None:

        super().__init__()

        self.latent_dim = latent_dim
        num_hidden_layes = int(np.log2(img_size))

        self.encoder = Encoder(start_channels, num_hidden_layes, latent_dim)
        self.decoder = Decoder(start_channels, num_hidden_layes, latent_dim)

     def _encode(self, x):
        return self.encoder(x)
    
    def _decode(self, z):
        return self.decoder(z)

    def _calculate_loss(self,
             x: torch.tensor,
             ):
      
        batch_size = x.shape[0]
        z, mu, log_sigma = self._encode(x)
        x_pred = self._decode(z)

        recon_loss = F.mse_loss(x, x_pred, reduction='none')
        recon_loss = recon_loss.reshape(batch_size, -1).sum(dim=1)

        kl_loss = 0.5 * (mu ** 2 + (2 * log_sigma).exp()) - log_sigma - 0.5
        kl_loss = kl_loss.reshape(batch_size, -1).sum(dim=1)

        loss = recon_loss + kl_loss

        return loss.mean(), recon_loss.mean(), kl_loss.mean()

    def _test(self, test_dataloader: DataLoader) -> float:
        self.eval()
        sum_loss = 0
        sum_recon_loss = 0
        sum_kl_loss = 0
        n_elements = 0
        with torch.no_grad():
            for batch in test_dataloader:
                batch_size = batch.shape[0]
                batch = batch.to(device)

                loss, recon_loss kl_loss = self._calculate_loss(batch)
                sum_loss += batch_size * loss
                sum_recon_loss += batch_size * sum_recon_loss
                sum_kl_loss += batch_size * sum_kl_loss
                n_elements += batch_size

        return [
                sum_loss.item() / n_elements,
                sum_recon_loss.item() / n_elements,
                sum_kl_loss.item() / n_elements
                ]

    def fit(self,
            train_dataloader: DataLoader,
            test_dataloader: DataLoader,
            epochs: int = 20,
            lr: float = 1e-3,
            ) -> Tuple[np.ndarray, np.ndarray]:

        optim = Adam(sel.parameters(), lr=lr)
        test_losses.append(self._test(test_dataloader))

        for epoch in trange(epochs, desc="Training"):
            self.train()
            sum_loss = 0
            sum_recon_loss = 0
            sum_kl_loss = 0
            n_elements = 0
            for batch in train_dataloader:
                batch_size = batch.shape[0]
                batch = (batch.to(device) + torch.rand(batch.shape, device=device)) / 2.0

                loss = self._calculate_loss(batch)

                optim.zero_grad()
                loss.backward()
                torch.nn.utils.clip_grad_norm_(self.parameters(), 1)
                optim.step()

                sum_loss += batch_size * loss
                sum_recon_loss += batch_size * sum_recon_loss
                sum_kl_loss += batch_size * sum_kl_loss
                n_elements += batch_size

            train_losses.append([
                                 sum_loss.item() / n_elements,
                                 sum_recon_loss.item() / n_elements,
                                 sum_kl_loss.item() / n_elements
                                 ])
            test_losses.append(self._test(test_dataloader))
          
        return np.array(train_losses), np.array(test_losses)


    @torch.no_grad()
    def sample(self, n):
        z = torch.randn(n, self.latent_dim, device=device)
        samples = self.decoder(z) 
        return samples.cpu().numpy().transpose(0, 2, 3, 1)

# %% [markdown]
# ### Solution
# Fill out the function below and return the neccessary arguments. Feel free to create more cells if need be

# %%
def q1_a(train_data, test_data, dset_id):
    """
    train_data: An (n_train, 32, 32, 3) uint8 numpy array of color images with values in {0, ..., 255}
    test_data: An (n_test, 32, 32, 3) uint8 numpy array of color images with values in {0, ..., 255}
    dset_id: An identifying number of which dataset is given (1 or 2). Most likely
               used to set different hyperparameters for different datasets

    Returns
    - a (# of training iterations, 3) numpy array of full negative ELBO, reconstruction loss E[-log p(x|z)],
      and KL term E[KL(q(z|x) | p(z))] evaluated every minibatch
    - a (# of epochs + 1, 3) numpy array of full negative ELBO, reconstruciton loss E[-p(x|z)],
      and KL term E[KL(q(z|x) | p(z))] evaluated once at initialization and after each epoch
    - a (100, 32, 32, 3) numpy array of 100 samples from your VAE with values in {0, ..., 255}
    - a (100, 32, 32, 3) numpy array of 50 real image / reconstruction pairs
      FROM THE TEST SET with values in {0, ..., 255}
    - a (100, 32, 32, 3) numpy array of 10 interpolations of length 10 between
      pairs of test images. The output should be those 100 images flattened into
      the specified shape with values in {0, ..., 255}
    """
    """ YOUR CODE HERE """

# %% [markdown]
# ### Results
# Once you've finished `q1_a`, execute the cells below to visualize and save your results.

# %%
q1_save_results('a', 1, q1_a)
# Out:
# Final -ELBO: 104.0417, Recon Loss: 79.3798, KL Loss: 24.6620

# %%
q1_save_results('a', 2, q1_a)

# %%
q1_save_results('b', 2, q1_b)
